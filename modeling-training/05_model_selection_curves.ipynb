# %% [markdown]
# Notebook for visualizing model selection curves stored in pickle files

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pickle
import numpy as np
import os

# %%
sns.set_style("ticks")
sns.set_palette("Set2")
matplotlib.rcParams.update({'font.size': 20})

# %%
# model_pths = [
#     './data/model_selection/32/modular/modular_v3-full-base.pkl',
#     './data/model_selection/32/parities/parities_v3-full-base.pkl',
#     './data/model_selection/32/modular_ln/--base.pkl',
#     './data/model_selection/32/cifar100_v3/False_False/--base.pkl',
#     './data/model_selection/32/cifar100_v3/True_True/--base.pkl',
#     './data/model_selection/32/mnist_v2--base.pkl',
#     './data/model_selection/32/multiberts/multiberts_diag.pkl',
# ]
model_pths = [
    '../results/hmm/resnet18_0.1imb_weighted.pkl'
]

# %%
def plot(data):
    fig, ax1 = plt.subplots(figsize=(8, 4))
    palette = sns.color_palette("Set2")
    N = len(data['mean_scores'])
    x = np.arange(1, N+1)
    mean_scores = np.array(data['mean_scores'])
    std_scores = np.array(data['scores_stdev'])
    aics = np.array(data['aics'])
    bics = np.array(data['bics'])

    sns.lineplot(ax=ax1, x=x, y=data['mean_scores'], label='Log density', color=palette[0])
    ax1.fill_between(x, mean_scores - std_scores, mean_scores + std_scores, color='gray', alpha=0.2, label='Error band')

    ax2 = ax1.twinx()

    sns.lineplot(ax=ax2, x=x, y=aics, label='AIC', color=palette[1], linewidth=2)
    sns.lineplot(ax=ax2, x=x, y=bics, label='BIC', color=palette[2], linewidth=2)

    handles1, labels1 = ax1.get_legend_handles_labels()
    handles2, labels2 = ax2.get_legend_handles_labels()
    handles = handles1 + handles2
    labels = labels1 + labels2

    ax1.set_xlabel("Number of components")
    ax1.set_ylabel("Log density")
    ax2.set_ylabel("AIC/BIC")

    ax1.legend().remove()
    ax2.legend().remove()

    ax1.legend(handles, labels)
    return fig, ax1, ax2

# %%
for i, pth in enumerate(model_pths):
    file_name = os.path.splitext(os.path.basename(pth))[0]
    
    with open(pth, 'rb') as f:
        data = pickle.load(f)
        
    fig, ax1, ax2 = plot(data)
    # if i != 0:
    ax1.legend().remove()
        
    # fig.savefig(f"./figures/model_selection/{i}_{file_name}", dpi=300, bbox_inches='tight')
# Out:
# /home/ubuntu/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ubuntu/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ubuntu/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ubuntu/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ubuntu/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ubuntu/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 11
#       8 # if i != 0:
#       9 ax1.legend().remove()
# ---> 11 fig.savefig(f"./figures/model_selection/{i}_{file_name}", dpi=300, bbox_inches='tight')
#
# File ~/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/matplotlib/figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/matplotlib/backend_bases.py:2133, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2128     _api.warn_deprecated(
#    2129         "3.8", name="papertype='auto'", addendum="Pass an explicit paper type, "
#    2130         "'figure', or omit the *papertype* argument entirely.")
#    2132 # Remove the figure manager, if any, to avoid resizing the GUI widget.
# -> 2133 with cbook._setattr_cm(self, manager=None), \
#    2134      self._switch_canvas_and_return_print_method(format, backend) \
#    2135          as print_method, \
#    2136      cbook._setattr_cm(self.figure, dpi=dpi), \
#    2137      cbook._setattr_cm(self.figure.canvas, _device_pixel_ratio=1), \
#    2138      cbook._setattr_cm(self.figure.canvas, _is_saving=True), \
#    2139      ExitStack() as stack:
#    2141     for prop in ["facecolor", "edgecolor"]:
#    2142         color = locals()[prop]
#
# File ~/miniconda3/envs/emthanhcv/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/emthanhcv/lib/python3.10/site-packages/matplotlib/backend_bases.py:2029, in FigureCanvasBase._switch_canvas_and_return_print_method(self, fmt, backend)
#    2027     canvas_class = get_registered_canvas_class(fmt)
#    2028     if canvas_class is None:
# -> 2029         raise ValueError(
#    2030             "Format {!r} is not supported (supported formats: {})".format(
#    2031                 fmt, ", ".join(sorted(self.get_supported_filetypes()))))
#    2032     canvas = canvas_class(self.figure)
#    2033 canvas._is_saving = self._is_saving
#
# ValueError: Format '1imb_weighted' is not supported (supported formats: eps, jpeg, jpg, pdf, pgf, png, ps, raw, rgba, svg, svgz, tif, tiff, webp)
